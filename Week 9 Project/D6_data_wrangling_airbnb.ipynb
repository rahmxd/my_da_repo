# %% [markdown]
# ## Wrangling Airbnb Rental Listings in Seattle
#
# ### Goals of the Task
#
#
#
# There are three tables in the data set which was scraped from the airbnb website on different dates <br>
# *listings - each row is a unique rental property* <br>
# *reviews - each row is a review left by a guest after checking out of a property* <br>
# *calendar - each row is a date and property showing if it was available or unvailable on that date* <br>
#
# We want to use this data to try to understand how many airbnb properties are located close to less popular cycle hire stations and if any airbnb guest commented on transport in their reviews for those properties. This insight could be used to make decisions about the future of those cycle stations.
#
# - the three data tables are large and unmanageable in excel, are also slow to visualise in PowerBI
# - we want to focus on specific locations only
# - not all the columns will be useful to this analysis
# - potentially useful mentions of transport are embedded in the review text
# - there are different dates across the 3 data sets (date scraped, date of review, dates available)

# %% [markdown]
# #### Step 1 : use pandas to read the data from the 3 csv files to create 3 data frames (listings, reviews, calendar)
# - import pandas as pd
# - use pandas read_csv
# - ensure you are pointing at the correct file path for the data sources (you may have to navigate in your notebook!)

# %%
import pandas as pd
calendar = pd.read_csv('data/calendar.csv')
listings = pd.read_csv('data/listings.csv')
reviews = pd.read_csv('data/reviews.csv')

# %% [markdown]
# #### Step 2: preview each dataframe using pandas functions like .info() .head(), .tail() and .describe()
# - look out for nulls and missing data
# - any problematic data types
# - consider if you need to do anything about missing data (replace/ impute /ignore / drop)

# %%
calendar.info()
calendar.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  object
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
calendar.tail()
# Out:
#          listing_id        date available price
# 1393565    10208623  2016-12-29         f   NaN
# 1393566    10208623  2016-12-30         f   NaN
# 1393567    10208623  2016-12-31         f   NaN
# 1393568    10208623  2017-01-01         f   NaN
# 1393569    10208623  2017-01-02         f   NaN

# %%
calendar.describe()
# Out:
#          listing_id
# count  1.393570e+06
# mean   5.550111e+06
# std    2.962274e+06
# min    3.335000e+03
# 25%    3.258213e+06
# 50%    6.118244e+06
# 75%    8.035212e+06
# max    1.034016e+07

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   date_scraped                      3818 non-null   object
#  2   name                              3818 non-null   object
#  3   summary                           3641 non-null   object
#  4   space                             3249 non-null   object
#  5   description                       3818 non-null   object
#  6   transit                           2884 non-null   object
#  7   host_id                           3818 non-null   int64
#  8   host_response_time                3295 non-null   object
#  9   host_response_rate                3295 non-null   object
#  10  host_acceptance_rate              3045 non-null   object
#  11  host_is_superhost                 3816 non-null   object
#  12  host_listings_count               3816 non-null   float64
#  13  host_total_listings_count         3816 non-null   float64
#  14  neighbourhood                     3818 non-null   object
#  15  neighbourhood_group               3818 non-null   object
#  16  city                              3818 non-null   object
#  17  state                             3818 non-null   object
#  18  zipcode                           3811 non-null   object
#  19  market                            3818 non-null   object
#  20  smart_location                    3818 non-null   object
#  21  country_code                      3818 non-null   object
#  22  country                           3818 non-null   object
#  23  latitude                          3818 non-null   float64
#  24  longitude                         3818 non-null   float64
#  25  is_location_exact                 3818 non-null   object
#  26  property_type                     3817 non-null   object
#  27  room_type                         3818 non-null   object
#  28  accommodates                      3818 non-null   int64
#  29  bathrooms                         3802 non-null   float64
#  30  bedrooms                          3812 non-null   float64
#  31  beds                              3817 non-null   float64
#  32  bed_type                          3818 non-null   object
#  33  amenities                         3818 non-null   object
#  34  square_feet                       97 non-null     float64
#  35  price                             3818 non-null   object
#  36  weekly_price                      2009 non-null   object
#  37  monthly_price                     1517 non-null   object
#  38  security_deposit                  1866 non-null   object
#  39  cleaning_fee                      2788 non-null   object
#  40  guests_included                   3818 non-null   int64
#  41  extra_people                      3818 non-null   object
#  42  minimum_nights                    3818 non-null   int64
#  43  maximum_nights                    3818 non-null   int64
#  44  calendar_updated                  3818 non-null   object
#  45  has_availability                  3818 non-null   object
#  46  availability_30                   3818 non-null   int64
#  47  availability_60                   3818 non-null   int64
#  48  availability_90                   3818 non-null   int64
#  49  availability_365                  3818 non-null   int64
#  50  number_of_reviews                 3818 non-null   int64
#  51  first_review                      3191 non-null   object
#  52  last_review                       3191 non-null   object
#  53  review_scores_rating              3171 non-null   float64
#  54  review_scores_accuracy            3160 non-null   float64
#  55  review_scores_cleanliness         3165 non-null   float64
#  56  review_scores_checkin             3160 non-null   float64
#  57  review_scores_communication       3167 non-null   float64
#  58  review_scores_location            3163 non-null   float64
#  59  review_scores_value               3162 non-null   float64
#  60  instant_bookable                  3818 non-null   object
#  61  cancellation_policy               3818 non-null   object
#  62  require_guest_profile_picture     3818 non-null   object
#  63  require_guest_phone_verification  3818 non-null   object
#  64  reviews_per_month                 3191 non-null   float64
# dtypes: float64(16), int64(11), object(38)
# memory usage: 1.9+ MB

# %%
listings.id.min()
# Out:
# 3335

# %%
listings.describe()
# Out:
#                  id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  1.578556e+07             7.157757
# std    2.962660e+06  1.458382e+07            28.628149
# min    3.335000e+03  4.193000e+03             1.000000
# 25%    3.258256e+06  3.275204e+06             1.000000
# 50%    6.118244e+06  1.055814e+07             1.000000
# 75%    8.035127e+06  2.590309e+07             3.000000
# max    1.034016e+07  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# min                     1.000000    47.505088  -122.417219      1.000000
# 25%                     1.000000    47.609418  -122.354321      2.000000
# 50%                     1.000000    47.623601  -122.328874      3.000000
# 75%                     3.000000    47.662694  -122.310800      4.000000
# max                   502.000000    47.733358  -122.240607     16.000000
#
#          bathrooms     bedrooms         beds  ...  availability_365  \
# count  3802.000000  3812.000000  3817.000000  ...       3818.000000
# mean      1.259469     1.307712     1.735394  ...        244.772656
# std       0.590369     0.883395     1.139480  ...        126.772526
# min       0.000000     0.000000     1.000000  ...          0.000000
# 25%       1.000000     1.000000     1.000000  ...        124.000000
# 50%       1.000000     1.000000     1.000000  ...        308.000000
# 75%       1.000000     2.000000     2.000000  ...        360.000000
# max       8.000000     7.000000    15.000000  ...        365.000000
#
#        number_of_reviews  review_scores_rating  review_scores_accuracy  \
# count        3818.000000           3171.000000             3160.000000
# mean           22.223415             94.539262                9.636392
# std            37.730892              6.606083                0.698031
# min             0.000000             20.000000                2.000000
# 25%             2.000000             93.000000                9.000000
# 50%             9.000000             96.000000               10.000000
# 75%            26.000000             99.000000               10.000000
# max           474.000000            100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                3165.000000            3160.000000
# mean                    9.556398               9.786709
# std                     0.797274               0.595499
# min                     3.000000               2.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                  3167.000000             3163.000000
# mean                      9.809599                9.608916
# std                       0.568211                0.629053
# min                       2.000000                4.000000
# 25%                      10.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  reviews_per_month
# count          3162.000000        3191.000000
# mean              9.452245           2.078919
# std               0.750259           1.822348
# min               2.000000           0.020000
# 25%               9.000000           0.695000
# 50%              10.000000           1.540000
# 75%              10.000000           3.000000
# max              10.000000          12.150000
#
# [8 rows x 27 columns]

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84849 entries, 0 to 84848
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   84849 non-null  int64
#  1   id           84849 non-null  int64
#  2   date         84849 non-null  object
#  3   reviewer_id  84849 non-null  int64
#  4   comments     84831 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 3.2+ MB

# %%
reviews.describe()
# Out:
#          listing_id            id   reviewer_id
# count  8.484900e+04  8.484900e+04  8.484900e+04
# mean   3.005067e+06  3.058765e+07  1.701301e+07
# std    2.472877e+06  1.636613e+07  1.353704e+07
# min    4.291000e+03  3.721000e+03  1.500000e+01
# 25%    7.946330e+05  1.725127e+07  5.053141e+06
# 50%    2.488228e+06  3.228809e+07  1.413476e+07
# 75%    4.694479e+06  4.457648e+07  2.762402e+07
# max    1.024814e+07  5.873651e+07  5.281274e+07

# %%
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id  \
# 0     7202016  38917982  19/07/2015     28943674
# 1     7202016  39087409  20/07/2015     32440555
# 2     7202016  39820030  26/07/2015     37722850
# 3     7202016  40813543  02/08/2015     33671805
# 4     7202016  41986501  10/08/2015     34959538
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %% [markdown]
# #### Step 3: detect and manage any duplicate rows using pandas .duplicated()
# - consider what a true duplicate is in each data frame
# - decide whether to drop the duplicates entirely or to review and try to understand why it exists
# - if you drop any rows, remember to reset your index on the dataframe afterwards using .reset_index(inplace=True,drop=True)

# %%
# Detect and manage duplicates in 'listings'
listings_duplicates = listings.duplicated()
listings = listings[~listings_duplicates].reset_index(drop=True)

# Detect and manage duplicates in 'reviews'
reviews_duplicates = reviews.duplicated()
reviews = reviews[~reviews_duplicates].reset_index(drop=True)

# Detect and manage duplicates in 'calendar'
calendar_duplicates = calendar.duplicated()
calendar = calendar[~calendar_duplicates].reset_index(drop=True)

# %%
listings.info()
reviews.info()
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   date_scraped                      3818 non-null   object
#  2   name                              3818 non-null   object
#  3   summary                           3641 non-null   object
#  4   space                             3249 non-null   object
#  5   description                       3818 non-null   object
#  6   transit                           2884 non-null   object
#  7   host_id                           3818 non-null   int64
#  8   host_response_time                3295 non-null   object
#  9   host_response_rate                3295 non-null   object
#  10  host_acceptance_rate              3045 non-null   object
#  11  host_is_superhost                 3816 non-null   object
#  12  host_listings_count               3816 non-null   float64
#  13  host_total_listings_count         3816 non-null   float64
#  14  neighbourhood                     3818 non-null   object
#  15  neighbourhood_group               3818 non-null   object
#  16  city                              3818 non-null   object
#  17  state                             3818 non-null   object
#  18  zipcode                           3811 non-null   object
#  19  market                            3818 non-null   object
#  20  smart_location                    3818 non-null   object
#  21  country_code                      3818 non-null   object
#  22  country                           3818 non-null   object
#  23  latitude                          3818 non-null   float64
#  24  longitude                         3818 non-null   float64
#  25  is_location_exact                 3818 non-null   object
#  26  property_type                     3817 non-null   object
#  27  room_type                         3818 non-null   object
#  28  accommodates                      3818 non-null   int64
#  29  bathrooms                         3802 non-null   float64
#  30  bedrooms                          3812 non-null   float64
#  31  beds                              3817 non-null   float64
#  32  bed_type                          3818 non-null   object
#  33  amenities                         3818 non-null   object
#  34  square_feet                       97 non-null     float64
#  35  price                             3818 non-null   object
#  36  weekly_price                      2009 non-null   object
#  37  monthly_price                     1517 non-null   object
#  38  security_deposit                  1866 non-null   object
#  39  cleaning_fee                      2788 non-null   object
#  40  guests_included                   3818 non-null   int64
#  41  extra_people                      3818 non-null   object
#  42  minimum_nights                    3818 non-null   int64
#  43  maximum_nights                    3818 non-null   int64
#  44  calendar_updated                  3818 non-null   object
#  45  has_availability                  3818 non-null   object
#  46  availability_30                   3818 non-null   int64
#  47  availability_60                   3818 non-null   int64
#  48  availability_90                   3818 non-null   int64
#  49  availability_365                  3818 non-null   int64
#  50  number_of_reviews                 3818 non-null   int64
#  51  first_review                      3191 non-null   object
#  52  last_review                       3191 non-null   object
#  53  review_scores_rating              3171 non-null   float64
#  54  review_scores_accuracy            3160 non-null   float64
#  55  review_scores_cleanliness         3165 non-null   float64
#  56  review_scores_checkin             3160 non-null   float64
#  57  review_scores_communication       3167 non-null   float64
#  58  review_scores_location            3163 non-null   float64
#  59  review_scores_value               3162 non-null   float64
#  60  instant_bookable                  3818 non-null   object
#  61  cancellation_policy               3818 non-null   object
#  62  require_guest_profile_picture     3818 non-null   object
#  63  require_guest_phone_verification  3818 non-null   object
#  64  reviews_per_month                 3191 non-null   float64
# dtypes: float64(16), int64(11), object(38)
# memory usage: 1.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84849 entries, 0 to 84848
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   84849 non-null  int64
#  1   id           84849 non-null  int64
#  2   date         84849 non-null  object
#  3   reviewer_id  84849 non-null  int64
#  4   comments     84831 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 3.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  object
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB

# %% [markdown]
# #### step 4: filter the listings data frame and reduce the number of columns
#
# We want to identify airbnb properties listed near to locations of less popular cycle stations found in the cycle hire data using pandas .query()
#
# This is the location information we know about the stations:
#
# - station WF-03 (160 trips from here) zipcode 98121 lat/long 47.6114 -122.349 Alaskan Way Belltown
# - station SLU-22 (761 trips from here) zipcode 98109 lat/long 47.6209 -122.347 Thomas Street South Lake Union  <br>
#
# You will have to identify columns in the listings dataframe which containing matching location information.
#
# Next, reduce the number of columns in this data frame to those which will be likely useful to analyse the sample of properties. You should keep the Id, Host Id, some location information and some columns about the space eg property type, no of bedrooms

# %%
listings_columns_to_keep = [
    'id', 'name', 'summary', 'space', 'description', 'transit',
    'host_id', 'neighbourhood', 'neighbourhood_group', 'zipcode',
    'latitude', 'longitude', 'property_type', 'beds'
]

# Create a new DataFrame with the specified columns
filtered_listings = listings[listings_columns_to_keep].copy()

# Display the new DataFrame
filtered_listings.head(3)
# Out:
#         id                                 name  \
# 0   241032         Stylish Queen Anne Apartment
# 1   953595   Bright & Airy Queen Anne Apartment
# 2  3308979  New Modern House-Amazing water view
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
#
#                                          description  \
# 0  Make your self at home in this charming one-be...
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
#
#                                              transit   host_id  \
# 0                                                NaN    956883
# 1  Convenient bus stops are just down the block, ...   5177328
# 2  A bus stop is just 2 blocks away.   Easy bus a...  16708587
#
#      neighbourhood neighbourhood_group zipcode   latitude   longitude  \
# 0  West Queen Anne          Queen Anne   98119  47.636289 -122.371025
# 1  West Queen Anne          Queen Anne   98119  47.639123 -122.365667
# 2  West Queen Anne          Queen Anne   98119  47.629724 -122.369483
#
#   property_type  beds
# 0     Apartment   1.0
# 1     Apartment   1.0
# 2         House   7.0

# %%
# Use .query() to filter listings based on the provided station locations
stations_query = filtered_listings.query(
    "(zipcode == '98121' or latitude == 47.6114 or longitude == -122.349) or " +
    "(zipcode == '98109' or latitude == 47.6209 or longitude == -122.347)"
)

# Display the filtered listings DataFrame
# 398
stations_query.head(5)
# Out:
#           id                                name  \
# 8    4948745    Urban Charm || Downtown || Views
# 39   6389657         Cute little Seattle Studio!
# 44   6575380             One bedroom with Lounge
# 199  3768745     Downtown Queen Anne large suite
# 200  3975434  One private bedroom in a large Apt
#
#                                                summary  \
# 8    Nestled in the heart of the city, this space i...
# 39   I love my little studio! My space might be sma...
# 44   This large, remodeled daylight basement space ...
# 199  Gorgeous professionally decorated suite in 192...
# 200  This bedroom is yours and it comes with the sh...
#
#                                                  space  \
# 8    Located in the heart of the city, this space i...
# 39   The patio has a table and chairs and potted pl...
# 44   With a comfortable space for lounging and havi...
# 199  As a fellow traveler to over 75 countries, I u...
# 200  This is a great apartment in a great neighborh...
#
#                                            description  \
# 8    Nestled in the heart of the city, this space i...
# 39   I love my little studio! My space might be sma...
# 44   This large, remodeled daylight basement space ...
# 199  Gorgeous professionally decorated suite in 192...
# 200  This bedroom is yours and it comes with the sh...
#
#                                                transit   host_id  \
# 8    Bus stop to downtown directly across the stree...   2166277
# 39   The area is very walkable, though there is a b...   2052160
# 44   Only five minutes from the bus stop to take yo...  34392395
# 199  Half a dozen bus lines stop within a block of ...  19311504
# 200  There is the monorail although I would only ad...   6307839
#
#        neighbourhood neighbourhood_group zipcode   latitude   longitude  \
# 8    West Queen Anne          Queen Anne   98109  47.632410 -122.357216
# 39   West Queen Anne          Queen Anne   98109  47.634616 -122.358023
# 44   West Queen Anne          Queen Anne   98109  47.634300 -122.357060
# 199  East Queen Anne          Queen Anne   98109  47.631843 -122.345123
# 200  East Queen Anne          Queen Anne   98109  47.628120 -122.348752
#
#     property_type  beds
# 8       Apartment   1.0
# 39      Apartment   1.0
# 44          House   1.0
# 199         House   1.0
# 200     Apartment   1.0

# %%
import numpy as np

# Tolerance for float comparisons
tolerance = 1e-3

# Check for approximate matches within the tolerance
filtered_dfWF = stations_query[np.isclose(stations_query['latitude'], 47.6114, atol=tolerance) & np.isclose(stations_query['longitude'], -122.349, atol=tolerance)]

# Display the filtered DataFrame
filtered_dfWF
# Out:
#            id                                 name  \
# 1212  5736082     Living room in 1 BHK for females
# 1284  7807169    Amazing Views of Elliott Bay! AH2
# 1388  1857141          Charming studio in Belltown
# 1390  8517235                     Heart of Seattle
# 1432  7440415  1BR 2 Blocks frm Pike Market & Pool
#
#                                                 summary  \
# 1212  Hi, I have living room available for rent in 1...
# 1284  This 2-bed, 2-bath condo sleeps 6 and includes...
# 1388  This comfortable studio sleeps two, has a full...
# 1390  My apartment is 1 block from the Pike Place Ma...
# 1432  Make yourself at home in a large one bedroom a...
#
#                                                   space  \
# 1212  Hi, I have living room available for rent in m...
# 1284  ArtHouse takes center stage in Belltown as one...
# 1388  Live like the locals do! This is a charming st...
# 1390                                                NaN
# 1432  I am offering my private apartment in a great ...
#
#                                             description  \
# 1212  Hi, I have living room available for rent in 1...
# 1284  This 2-bed, 2-bath condo sleeps 6 and includes...
# 1388  This comfortable studio sleeps two, has a full...
# 1390  My apartment is 1 block from the Pike Place Ma...
# 1432  Make yourself at home in a large one bedroom a...
#
#                                                 transit   host_id  \
# 1212  Lot of buses near this place. westlake transit...  29745749
# 1284  Convenient public transportation. The location...   4962900
# 1388  Very convenient transit, train from airport st...   9691769
# 1390                                                NaN  44846373
# 1432                                                NaN  30499792
#
#      neighbourhood neighbourhood_group zipcode   latitude   longitude  \
# 1212      Belltown            Downtown   98121  47.611090 -122.348157
# 1284      Belltown            Downtown   98121  47.612499 -122.348258
# 1388      Belltown            Downtown   98121  47.611477 -122.348518
# 1390      Belltown            Downtown   98121  47.611711 -122.347532
# 1432      Belltown            Downtown   98121  47.611165 -122.347545
#
#      property_type  beds
# 1212     Apartment   1.0
# 1284     Apartment   3.0
# 1388     Apartment   2.0
# 1390     Apartment   1.0
# 1432     Apartment   1.0

# %%
# Tolerance for float comparisons
tolerance = 1e-3

# Check for approximate matches within the tolerance
filtered_dfSLU = stations_query[np.isclose(stations_query['latitude'], 47.6209, atol=tolerance) & np.isclose(stations_query['longitude'], -122.347, atol=tolerance)]

# Display the filtered DataFrame
filtered_dfSLU
# Out:
#            id                    name  \
# 1146  8829089  In the heart of it all
#
#                                                 summary  \
# 1146  Great location with  comfortable accommodation...
#
#                                                   space  \
# 1146  you will have occupy the master bedroom with a...
#
#                                             description  \
# 1146  Great location with  comfortable accommodation...
#
#                                                 transit   host_id  \
# 1146  Seattle is a drivers nightmare generally speak...  25855544
#
#          neighbourhood neighbourhood_group zipcode   latitude   longitude  \
# 1146  South Lake Union             Cascade   98109  47.619917 -122.346108
#
#      property_type  beds
# 1146     Apartment   1.0

# %% [markdown]
# #### Step 5: obtain a list of unique listing ids from the calendar table which show properties available for rent on any day in August 2016
#
# - note that it is not possible to do this using excel due to the large size of the file
# - extract the unique values from the dataframe using unique()
# - convert the series to a list
# - use the list of ids to filter the listings table with a pandas query

# %%
calendar['date'] = pd.to_datetime(calendar['date'].str.strip(), format='%Y-%m-%d')

# %%
august_listings_ids = calendar.loc[
    (calendar['date'].dt.year == 2016) & (calendar['date'].dt.month == 8) & (calendar['available'] == 't')]

unique_listing = august_listings_ids['listing_id'].unique()
# len(unique_listing)
list(unique_listing)

# filter listings dataframe with the unique list of ids available for august 8 2016
filtered_list_august = filtered_listings.query('id in @unique_listing')
filtered_list_august.head(5)
# Out:
#         id                                 name  \
# 0   241032         Stylish Queen Anne Apartment
# 1   953595   Bright & Airy Queen Anne Apartment
# 2  3308979  New Modern House-Amazing water view
# 3  7421966                   Queen Anne Chateau
# 4   278830       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description  \
# 0  Make your self at home in this charming one-be...
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                              transit   host_id  \
# 0                                                NaN    956883
# 1  Convenient bus stops are just down the block, ...   5177328
# 2  A bus stop is just 2 blocks away.   Easy bus a...  16708587
# 3                                                NaN   9851441
# 4  The nearest public transit bus (D Line) is 2 b...   1452570
#
#      neighbourhood neighbourhood_group zipcode   latitude   longitude  \
# 0  West Queen Anne          Queen Anne   98119  47.636289 -122.371025
# 1  West Queen Anne          Queen Anne   98119  47.639123 -122.365667
# 2  West Queen Anne          Queen Anne   98119  47.629724 -122.369483
# 3  West Queen Anne          Queen Anne   98119  47.638473 -122.369279
# 4  West Queen Anne          Queen Anne   98119  47.632918 -122.372471
#
#   property_type  beds
# 0     Apartment   1.0
# 1     Apartment   1.0
# 2         House   7.0
# 3     Apartment   2.0
# 4         House   3.0

# %% [markdown]
# #### Step 6: combine the data sources into a new data frame
# - the Id in the listings table and the Listing Id in reviews are the relevant keys to use
# - use the pandas merge method
# - the data frame should contain a subset of columns that you consider useful to analyse airbnb properties near the 2 least popular cycle stations, plus the review text column
# - the data frame should only contain properties that were available for rent at August 2016
# - the data frame should contain only the reviews those properties received in the period matching our cycle hire sample dates (2014-2016)

# %%
stations_query.rename(columns={'id':'listing_id'}, inplace=True)
merged_and_reviews_inner = reviews.merge(stations_query, how="inner")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_388\3393395357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_query.rename(columns={'id':'listing_id'}, inplace=True)

# %%
merged_august_and_reviews_inner
# Out:
#       listing_id        id        date  reviewer_id  \
# 0        7833113  44472406  26/08/2015     34123551
# 1        7833113  45156782  31/08/2015     13316300
# 2        7833113  45704944  05/09/2015      7354543
# 3        7833113  46177947  08/09/2015     16840700
# 4        7833113  46752160  13/09/2015     23038979
# ...          ...       ...         ...          ...
# 7530     6781308  56513469  14/12/2015     39312228
# 7531     6781308  56817099  18/12/2015     50993517
# 7532      830948   4665466  19/05/2013      6079208
# 7533      830948  20420393  29/09/2014     19157125
# 7534      830948  47078443  15/09/2015     41852334
#
#                                                comments  \
# 0     Kelli was an amazing host and immediately open...
# 1     First and foremost Kelli went out of her way t...
# 2     Convenient location close to Music Museum. Eas...
# 3     Kelli made my friend and I feel extremely welc...
# 4     Kelli was so sweet and made us feel welcome ri...
# ...                                                 ...
# 7530  From start to finish Tim was always there when...
# 7531  Timothy checked to make sure we got to the apa...
# 7532  I traveled cross-country from Florida to Seatt...
# 7533  Pam was a kind, welcoming host. She offered to...
# 7534  It was a lovely stay into Pam's sweet apartmen...
#
#                                      name  \
# 0      Prime Location to Explore Seattle!
# 1      Prime Location to Explore Seattle!
# 2      Prime Location to Explore Seattle!
# 3      Prime Location to Explore Seattle!
# 4      Prime Location to Explore Seattle!
# ...                                   ...
# 7530  Heart of Seattle, minutes to it all
# 7531  Heart of Seattle, minutes to it all
# 7532  City & Lake Views. Central- shared
# 7533  City & Lake Views. Central- shared
# 7534  City & Lake Views. Central- shared
#
#                                                 summary  \
# 0     Come explore Seattle! Private room/den with fu...
# 1     Come explore Seattle! Private room/den with fu...
# 2     Come explore Seattle! Private room/den with fu...
# 3     Come explore Seattle! Private room/den with fu...
# 4     Come explore Seattle! Private room/den with fu...
# ...                                                 ...
# 7530  Our beautiful newly renovated vacation rental ...
# 7531  Our beautiful newly renovated vacation rental ...
# 7532                                                NaN
# 7533                                                NaN
# 7534                                                NaN
#
#                                                   space  \
# 0     My home is in a vintage brick apartment buildi...
# 1     My home is in a vintage brick apartment buildi...
# 2     My home is in a vintage brick apartment buildi...
# 3     My home is in a vintage brick apartment buildi...
# 4     My home is in a vintage brick apartment buildi...
# ...                                                 ...
# 7530  Newly renovated one bedroom, one bath apartmen...
# 7531  Newly renovated one bedroom, one bath apartmen...
# 7532  My condo is located in the center of Seattle. ...
# 7533  My condo is located in the center of Seattle. ...
# 7534  My condo is located in the center of Seattle. ...
#
#                                             description  \
# 0     Come explore Seattle! Private room/den with fu...
# 1     Come explore Seattle! Private room/den with fu...
# 2     Come explore Seattle! Private room/den with fu...
# 3     Come explore Seattle! Private room/den with fu...
# 4     Come explore Seattle! Private room/den with fu...
# ...                                                 ...
# 7530  Our beautiful newly renovated vacation rental ...
# 7531  Our beautiful newly renovated vacation rental ...
# 7532  My condo is located in the center of Seattle. ...
# 7533  My condo is located in the center of Seattle. ...
# 7534  My condo is located in the center of Seattle. ...
#
#                                                 transit   host_id  \
# 0     You can catch the Link light rail from Sea-Tac...   5203265
# 1     You can catch the Link light rail from Sea-Tac...   5203265
# 2     You can catch the Link light rail from Sea-Tac...   5203265
# 3     You can catch the Link light rail from Sea-Tac...   5203265
# 4     You can catch the Link light rail from Sea-Tac...   5203265
# ...                                                 ...       ...
# 7530  Many of our guests bike or walk. If you choose...  33944952
# 7531  Many of our guests bike or walk. If you choose...  33944952
# 7532                                                NaN   4133860
# 7533                                                NaN   4133860
# 7534                                                NaN   4133860
#
#          neighbourhood neighbourhood_group zipcode   latitude   longitude  \
# 0     South Lake Union             Cascade   98109  47.623861 -122.342263
# 1     South Lake Union             Cascade   98109  47.623861 -122.342263
# 2     South Lake Union             Cascade   98109  47.623861 -122.342263
# 3     South Lake Union             Cascade   98109  47.623861 -122.342263
# 4     South Lake Union             Cascade   98109  47.623861 -122.342263
# ...                ...                 ...     ...        ...         ...
# 7530   East Queen Anne          Queen Anne   98109  47.642192 -122.346430
# 7531   East Queen Anne          Queen Anne   98109  47.642192 -122.346430
# 7532          Westlake             Cascade   98109  47.633474 -122.343445
# 7533          Westlake             Cascade   98109  47.633474 -122.343445
# 7534          Westlake             Cascade   98109  47.633474 -122.343445
#
#      property_type  beds
# 0        Apartment   1.0
# 1        Apartment   1.0
# 2        Apartment   1.0
# 3        Apartment   1.0
# 4        Apartment   1.0
# ...            ...   ...
# 7530     Apartment   2.0
# 7531     Apartment   2.0
# 7532     Apartment   1.0
# 7533     Apartment   1.0
# 7534     Apartment   1.0
#
# [7535 rows x 18 columns]

# %%
 = stations_query.query('id in @unique_listing')
filtered_list_august.head(5)

# %% [markdown]
# #### Step 7: check for the mentions of transportation, transport, cycling or bikes in the review text
#
# - in the review column you will find sentences
# - you can utilise any of the methods you encountered in the week 8 text analysis topic
# - for example, you can use pandas str contain function, or regexp pattern matching
# - the aim is to flag all the reviews which contains reference to transport or transportation, cycling, bikes etc

# %% [markdown]
# #### Step 8: data visualisations
# - visualise the number of listings, beds per room type of properties you have found close to the cycle stations mentioned
# - then visualise how many reviews for those properties mentioned the theme of transport
