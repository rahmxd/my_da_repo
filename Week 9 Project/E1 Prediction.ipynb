# %%
import pandas as pd

# %%
weather = pd.read_csv('data/Seattle_weather_daily.csv')
hires = pd.read_csv('data/Seattle_cycles_trip.csv')
stations = pd.read_csv('data/Seattle_cycles_station.csv')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11472\3937338.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   hires = pd.read_csv('data/Seattle_cycles_trip.csv')

# %%
weather.head(5)
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
# 3  10/16/2014                 71                61.0                52
# 4  10/17/2014                 64                60.0                57
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
# 3               49               46              42            83
# 4               55               51              41            87
#
#    Mean_Humidity  Min_Humidity  ...  Mean_Sea_Level_Pressure_In  \
# 0             68            46  ...                       29.79
# 1             78            63  ...                       29.75
# 2             77            67  ...                       29.71
# 3             61            36  ...                       29.95
# 4             72            46  ...                       29.78
#
#    Min_Sea_Level_Pressure_In  Max_Visibility_Miles  Mean_Visibility_Miles  \
# 0                      29.65                    10                     10
# 1                      29.54                    10                      9
# 2                      29.51                    10                      9
# 3                      29.81                    10                     10
# 4                      29.73                    10                     10
#
#    Min_Visibility_Miles  Max_Wind_Speed_MPH  Mean_Wind_Speed_MPH  \
# 0                     4                  13                    4
# 1                     3                  10                    5
# 2                     3                  18                    7
# 3                    10                   9                    4
# 4                     6                   8                    3
#
#    Max_Gust_Speed_MPH Precipitation_In  Events
# 0                  21             0.00    Rain
# 1                  17             0.11    Rain
# 2                  25             0.45    Rain
# 3                   -             0.00    Rain
# 4                   -             0.14    Rain
#
# [5 rows x 21 columns]

# %%
weather.dtypes
hires.dtypes
stations.dtypes
# Out:
# station_id            object
# name                  object
# lat                  float64
# long                 float64
# install_date          object
# install_dockcount      int64
# modification_date     object
# current_dockcount      int64
# decommission_date     object
# dtype: object

# %%
weather.columns = weather.columns.str.lower()
hires.columns = hires.columns.str.lower()
stations.columns = stations.columns.str.lower()

# %%
weather.columns
# Out:
# Index(['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperaturef',
#        'max_dew_point_f', 'meandew_point_f', 'min_dewpoint_f', 'max_humidity',
#        'mean_humidity', 'min_humidity', 'max_sea_level_pressure_in',
#        'mean_sea_level_pressure_in', 'min_sea_level_pressure_in',
#        'max_visibility_miles', 'mean_visibility_miles', 'min_visibility_miles',
#        'max_wind_speed_mph', 'mean_wind_speed_mph', 'max_gust_speed_mph',
#        'precipitation_in', 'events'],
#       dtype='object')

# %%
# Detect and manage duplicates in 'weather'
weather_duplicates = weather.duplicated()
weather = weather[~weather_duplicates].reset_index(drop=True)

# %%
weather_columns_to_keep = [
    'date', 'max_temperature_f', 'mean_temperature_f', 
    'min_temperaturef', 'max_wind_speed_mph', 
    'mean_wind_speed_mph', 'max_gust_speed_mph', 
    'precipitation_in', 'events']

# Create a new DataFrame with the specified columns
filtered_weather = weather[weather_columns_to_keep].copy()

# Display the new DataFrame
filtered_weather.head(3)
# Out:
#          date  max_temperature_f  mean_temperature_f  min_temperaturef  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
#
#    max_wind_speed_mph  mean_wind_speed_mph max_gust_speed_mph  \
# 0                  13                    4                 21
# 1                  10                    5                 17
# 2                  18                    7                 25
#
#    precipitation_in events
# 0              0.00   Rain
# 1              0.11   Rain
# 2              0.45   Rain

# %%
# change date objects to datetimes
weather['date'] = pd.to_datetime(weather['date'].str.strip(), format='%m/%d/%Y')
weather.head(2)
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperaturef  \
# 0 2014-10-13                 71                62.0                54
# 1 2014-10-14                 63                59.0                55
#
#    max_dew_point_f  meandew_point_f  min_dewpoint_f  max_humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
#
#    mean_humidity  min_humidity  ...  mean_sea_level_pressure_in  \
# 0             68            46  ...                       29.79
# 1             78            63  ...                       29.75
#
#    min_sea_level_pressure_in  max_visibility_miles  mean_visibility_miles  \
# 0                      29.65                    10                     10
# 1                      29.54                    10                      9
#
#    min_visibility_miles  max_wind_speed_mph  mean_wind_speed_mph  \
# 0                     4                  13                    4
# 1                     3                  10                    5
#
#    max_gust_speed_mph precipitation_in  events
# 0                  21             0.00    Rain
# 1                  17             0.11    Rain
#
# [2 rows x 21 columns]

# %%
stations.head(3)
# Out:
#   station_id                    name        lat        long install_date  \
# 0      BT-01      3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03       2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 2      BT-04  6th Ave & Blanchard St  47.616094 -122.341102   10/13/2014
#
#    install_dockcount modification_date  current_dockcount decommission_date
# 0                 18               NaN                 18               NaN
# 1                 16               NaN                 16               NaN
# 2                 16               NaN                 16               NaN

# %%
# stations.decommission_date.unique to check which stations were decommisioned as we don't need them

filtered_stations = stations[pd.isna(stations['decommission_date'])].copy()

# checked if decommisioned stations removed as no date present using
# filtered_stations.decommission_date.unique

# %%
stations_columns_to_keep = [
    'station_id', 'name', 'lat', 'long', 'install_date',
    'current_dockcount'
    ]

# Create a new DataFrame with the specified columns
filtered_stations = filtered_stations[stations_columns_to_keep].copy()

# Display the new DataFrame, should have 57 stations
filtered_stations.head(3)
# Out:
#   station_id                    name        lat        long install_date  \
# 0      BT-01      3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03       2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 2      BT-04  6th Ave & Blanchard St  47.616094 -122.341102   10/13/2014
#
#    current_dockcount
# 0                 18
# 1                 16
# 2                 16

# %%
# change date objects to datetimes
# filtered_stations['install_date'] = pd.to_datetime(filtered_stations['install_date'].str.strip(), format='%m/%d/%Y')
# filtered_stations.head(2)
filtered_stations['install_date'] = pd.to_datetime(filtered_stations['install_date'], format='%m/%d/%Y')
filtered_stations.head(2)
# Out:
#   station_id                name        lat        long install_date  \
# 0      BT-01  3rd Ave & Broad St  47.618418 -122.350964   2014-10-13
# 1      BT-03   2nd Ave & Vine St  47.615829 -122.348564   2014-10-13
#
#    current_dockcount
# 0                 18
# 1                 16

# %%
hires
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2           433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3           434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# ...         ...               ...               ...       ...           ...
# 286853   255241   8/31/2016 23:34   8/31/2016 23:45  SEA00201       679.532
# 286854   255242   8/31/2016 23:48  09/01/2016 00:20  SEA00247      1965.418
# 286855   255243   8/31/2016 23:47  09/01/2016 00:20  SEA00300      1951.173
# 286856   255244   8/31/2016 23:49  09/01/2016 00:20  SEA00047      1883.299
# 286857   255245   8/31/2016 23:49  09/01/2016 00:20  SEA00442      1896.031
#
#                              from_station_name  \
# 0                          2nd Ave & Spring St
# 1                          2nd Ave & Spring St
# 2                          2nd Ave & Spring St
# 3                          2nd Ave & Spring St
# 4                          2nd Ave & Spring St
# ...                                        ...
# 286853                 Harvard Ave & E Pine St
# 286854  Cal Anderson Park / 11th Ave & Pine St
# 286855  Cal Anderson Park / 11th Ave & Pine St
# 286856  Cal Anderson Park / 11th Ave & Pine St
# 286857  Cal Anderson Park / 11th Ave & Pine St
#
#                                           to_station_name from_station_id  \
# 0       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 1       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 2       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 3       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 4       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# ...                                                   ...             ...
# 286853                                2nd Ave & Spring St           CH-09
# 286854                              6th Ave S & S King St           CH-08
# 286855                              6th Ave S & S King St           CH-08
# 286856                              6th Ave S & S King St           CH-08
# 286857                              6th Ave S & S King St           CH-08
#
#        to_station_id                usertype  gender birthyear
# 0              PS-04                  Member    Male      1960
# 1              PS-04                  Member    Male      1970
# 2              PS-04                  Member  Female      1988
# 3              PS-04                  Member  Female      1977
# 4              PS-04                  Member    Male      1971
# ...              ...                     ...     ...       ...
# 286853        CBD-06  Short-Term Pass Holder     NaN       NaN
# 286854         ID-04  Short-Term Pass Holder     NaN       NaN
# 286855         ID-04  Short-Term Pass Holder     NaN       NaN
# 286856         ID-04  Short-Term Pass Holder     NaN       NaN
# 286857         ID-04  Short-Term Pass Holder     NaN       NaN
#
# [286858 rows x 12 columns]

# %%
hires.columns
# Out:
# Index(['trip_id', 'starttime', 'stoptime', 'bikeid', 'tripduration',
#        'from_station_name', 'to_station_name', 'from_station_id',
#        'to_station_id', 'usertype', 'gender', 'birthyear'],
#       dtype='object')

# %%
# wrote this code just to check the original dataframe for duplicates before removing
# hires.sort_values(by = 'trip_id', ascending = True).head(4)

# %%
# initial method of checking for duplicates in hires dataframe

# duplicates_hires = hires[hires.duplicated('trip_id', keep='first')].copy()
# duplicates_hires.sort_values(by = 'trip_id', ascending = True).head(3)

duplicates_hires = hires[hires.duplicated(['trip_id', 'tripduration'], keep='first')].copy()

# checked if they are actually duplicates by storing in dataframe and observing
# total of 50793 duplicate rows removed
duplicates_hires.sort_values(by='trip_id', ascending=True).head(4)
# Out:
#        trip_id         starttime          stoptime    bikeid  tripduration  \
# 50793      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 50794      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 50795      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 50796      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
#
#          from_station_name                                    to_station_name  \
# 50793  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 50794  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 50795  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 50796  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#       from_station_id to_station_id usertype  gender birthyear
# 50793          CBD-06         PS-04   Member    Male      1960
# 50794          CBD-06         PS-04   Member    Male      1970
# 50795          CBD-06         PS-04   Member  Female      1988
# 50796          CBD-06         PS-04   Member  Female      1977

# %%
# Drop duplicates based on both 'trip_id' and 'tripduration'
hires = hires.drop_duplicates(['trip_id', 'tripduration'], keep='first').reset_index(drop=True)
hires
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2           433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3           434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# ...         ...               ...               ...       ...           ...
# 236060   255241   8/31/2016 23:34   8/31/2016 23:45  SEA00201       679.532
# 236061   255242   8/31/2016 23:48  09/01/2016 00:20  SEA00247      1965.418
# 236062   255243   8/31/2016 23:47  09/01/2016 00:20  SEA00300      1951.173
# 236063   255244   8/31/2016 23:49  09/01/2016 00:20  SEA00047      1883.299
# 236064   255245   8/31/2016 23:49  09/01/2016 00:20  SEA00442      1896.031
#
#                              from_station_name  \
# 0                          2nd Ave & Spring St
# 1                          2nd Ave & Spring St
# 2                          2nd Ave & Spring St
# 3                          2nd Ave & Spring St
# 4                          2nd Ave & Spring St
# ...                                        ...
# 236060                 Harvard Ave & E Pine St
# 236061  Cal Anderson Park / 11th Ave & Pine St
# 236062  Cal Anderson Park / 11th Ave & Pine St
# 236063  Cal Anderson Park / 11th Ave & Pine St
# 236064  Cal Anderson Park / 11th Ave & Pine St
#
#                                           to_station_name from_station_id  \
# 0       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 1       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 2       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 3       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 4       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# ...                                                   ...             ...
# 236060                                2nd Ave & Spring St           CH-09
# 236061                              6th Ave S & S King St           CH-08
# 236062                              6th Ave S & S King St           CH-08
# 236063                              6th Ave S & S King St           CH-08
# 236064                              6th Ave S & S King St           CH-08
#
#        to_station_id                usertype  gender birthyear
# 0              PS-04                  Member    Male      1960
# 1              PS-04                  Member    Male      1970
# 2              PS-04                  Member  Female      1988
# 3              PS-04                  Member  Female      1977
# 4              PS-04                  Member    Male      1971
# ...              ...                     ...     ...       ...
# 236060        CBD-06  Short-Term Pass Holder     NaN       NaN
# 236061         ID-04  Short-Term Pass Holder     NaN       NaN
# 236062         ID-04  Short-Term Pass Holder     NaN       NaN
# 236063         ID-04  Short-Term Pass Holder     NaN       NaN
# 236064         ID-04  Short-Term Pass Holder     NaN       NaN
#
# [236065 rows x 12 columns]

# %%
hires_columns_to_keep = [
    'trip_id', 'starttime', 'stoptime', 'bikeid', 'tripduration',
    'from_station_id','to_station_id']

# Create a new DataFrame with the specified columns
hires = hires[hires_columns_to_keep].copy()

# Display the new DataFrame, should have 57 stations
hires.head(5)
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
#
#   from_station_id to_station_id
# 0          CBD-06         PS-04
# 1          CBD-06         PS-04
# 2          CBD-06         PS-04
# 3          CBD-06         PS-04
# 4          CBD-06         PS-04

# %%
hires['starttime'] = pd.to_datetime(hires['starttime'])  # Convert to datetime format

# Create new columns 'start_date' and 'start_time'
hires['start_date'] = hires['starttime'].dt.date
hires['start_time'] = hires['starttime'].dt.time

# Display the DataFrame with the new columns
hires[['starttime', 'start_date', 'start_time']].head(2)
# Out:
#             starttime  start_date start_time
# 0 2014-10-13 10:31:00  2014-10-13   10:31:00
# 1 2014-10-13 10:32:00  2014-10-13   10:32:00

# %%
hires['stoptime'] = pd.to_datetime(hires['stoptime'])  # Convert to datetime format

# Create new columns 'start_date' and 'start_time'
hires['stop_date'] = hires['stoptime'].dt.date
hires['stop_time'] = hires['stoptime'].dt.time

# Display the DataFrame with the new columns
hires[['stoptime', 'stop_date', 'stop_time']].head(2)
# Out:
#              stoptime   stop_date stop_time
# 0 2014-10-13 10:48:00  2014-10-13  10:48:00
# 1 2014-10-13 10:48:00  2014-10-13  10:48:00

# %%
hires = hires.drop(['starttime','stoptime'], axis=1)

# %%
hires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236065 entries, 0 to 236064
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   trip_id          236065 non-null  int64
#  1   bikeid           236065 non-null  object
#  2   tripduration     236065 non-null  float64
#  3   from_station_id  236065 non-null  object
#  4   to_station_id    236065 non-null  object
#  5   start_date       236065 non-null  object
#  6   start_time       236065 non-null  object
#  7   stop_date        236065 non-null  object
#  8   stop_time        236065 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 16.2+ MB

# %%
weather.head(2)
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperaturef  \
# 0 2014-10-13                 71                62.0                54
# 1 2014-10-14                 63                59.0                55
#
#    max_dew_point_f  meandew_point_f  min_dewpoint_f  max_humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
#
#    mean_humidity  min_humidity  ...  mean_sea_level_pressure_in  \
# 0             68            46  ...                       29.79
# 1             78            63  ...                       29.75
#
#    min_sea_level_pressure_in  max_visibility_miles  mean_visibility_miles  \
# 0                      29.65                    10                     10
# 1                      29.54                    10                      9
#
#    min_visibility_miles  max_wind_speed_mph  mean_wind_speed_mph  \
# 0                     4                  13                    4
# 1                     3                  10                    5
#
#    max_gust_speed_mph precipitation_in  events
# 0                  21             0.00    Rain
# 1                  17             0.11    Rain
#
# [2 rows x 21 columns]

# %%
filtered_stations.head(2)
# Out:
#   station_id                name        lat        long install_date  \
# 0      BT-01  3rd Ave & Broad St  47.618418 -122.350964   2014-10-13
# 1      BT-03   2nd Ave & Vine St  47.615829 -122.348564   2014-10-13
#
#    current_dockcount
# 0                 18
# 1                 16

# %%
filtered_stations.info()
hires.info()
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 57
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   station_id         54 non-null     object
#  1   name               54 non-null     object
#  2   lat                54 non-null     float64
#  3   long               54 non-null     float64
#  4   install_date       54 non-null     datetime64[ns]
#  5   current_dockcount  54 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 3.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236065 entries, 0 to 236064
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   trip_id          236065 non-null  int64
#  1   bikeid           236065 non-null  object
#  2   tripduration     236065 non-null  float64
#  3   from_station_id  236065 non-null  object
#  4   to_station_id    236065 non-null  object
#  5   start_date       236065 non-null  object
#  6   start_time       236065 non-null  object
#  7   stop_date        236065 non-null  object
#  8   stop_time        236065 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 16.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   date                        689 non-null    datetime64[ns]
#  1   max_temperature_f           689 non-null    int64
#  2   mean_temperature_f          688 non-null    float64
#  3   min_temperaturef            689 non-null    int64
#  4   max_dew_point_f             689 non-null    int64
#  5   meandew_point_f             689 non-null    int64
#  6   min_dewpoint_f              689 non-null    int64
#  7   max_humidity                689 non-null    int64
#  8   mean_humidity               689 non-null    int64
#  9   min_humidity                689 non-null    int64
#  10  max_sea_level_pressure_in   689 non-null    float64
#  11  mean_sea_level_pressure_in  689 non-null    float64
#  12  min_sea_level_pressure_in   689 non-null    float64
#  13  max_visibility_miles        689 non-null    int64
#  14  mean_visibility_miles       689 non-null    int64
#  15  min_visibility_miles        689 non-null    int64
#  16  max_wind_speed_mph          689 non-null    int64
#  17  mean_wind_speed_mph         689 non-null    int64
#  18  max_gust_speed_mph          504 non-null    object
#  19  precipitation_in            689 non-null    float64
#  20  events                      328 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(13), object(2)
# memory usage: 113.2+ KB

# %%
# connect weather with hires

merged_hires_stations = pd.merge(hires, filtered_stations, left_on='from_station_id', right_on='station_id', how='inner')

# Display the merged DataFrame
merged_hires_stations.info()

# connect station with (merged_weather_hires)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228812 entries, 0 to 228811
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   trip_id            228812 non-null  int64
#  1   bikeid             228812 non-null  object
#  2   tripduration       228812 non-null  float64
#  3   from_station_id    228812 non-null  object
#  4   to_station_id      228812 non-null  object
#  5   start_date         228812 non-null  object
#  6   start_time         228812 non-null  object
#  7   stop_date          228812 non-null  object
#  8   stop_time          228812 non-null  object
#  9   station_id         228812 non-null  object
#  10  name               228812 non-null  object
#  11  lat                228812 non-null  float64
#  12  long               228812 non-null  float64
#  13  install_date       228812 non-null  datetime64[ns]
#  14  current_dockcount  228812 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(9)
# memory usage: 27.9+ MB
