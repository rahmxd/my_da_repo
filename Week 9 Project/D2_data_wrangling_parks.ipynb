# %% [markdown]
# ## Wrangling parks data
#
# ### Goals of the Task
#
#
# The parks and recreation data consists of two data sets.
#
# - The smaller data set contains address, longitude and latitude for Seattle parks (each row is a park).
# - The second data set (features) indicates which facilities a park has (each row is a facility in a park) such as picnic areas, basketball courts and football pitches.
#
# The aim of this task is to combine and reshape the data into a wide rather than long frame where each row is a park, and there is a Boolean column for each feature type.

# %% [markdown]
# #### Step 1 : use pandas to read the parks and features data files into data frames
# - import pandas as pd
# - use pandas read_csv to create a parks data frame and a facilities data frame
# - ensure you are pointing at the correct file path for the data source (you may have to navigate in your notebook!)

# %%
import pandas as pd
df_parks = pd.read_csv('Data/Seattle_Parks_And_Recreation_Park_Addresses.csv')
df_facilities = pd.read_csv('Data/Seattle_Parks_and_Recreation_Parks_Features.csv')

# %%
df_parks.head(5)
# Out:
#    PMAID  LocID                     Name            Address  ZIP Code  \
# 0    281   2545  12th and Howe Play Park     1200 W Howe St     98119
# 1   4159   2387     12th Ave S Viewpoint    2821 12TH Ave S     98144
# 2   4467   2382     12th Ave Square Park       564 12th Ave     98122
# 3   4010   2546    14th Ave NW Boat Ramp   4400 14th Ave NW     98107
# 4    296    296           3001 E Madison  3001 E Madison St     98112
#
#       X Coord    Y Coord                Location 1
# 0 -122.372985  47.636097  (47.636097, -122.372985)
# 1 -122.317765  47.577953  (47.577953, -122.317765)
# 2 -122.316455  47.607427  (47.607427, -122.316455)
# 3 -122.373536  47.660775  (47.660775, -122.373536)
# 4 -122.293173  47.625169  (47.625169, -122.293173)

# %%
df_facilities.head(5)
# Out:
#    PMAID                     Name Alt_Name        xPos       yPos  Feature_ID  \
# 0    281  12th and Howe Play Park      NaN -122.372985  47.636097          22
# 1   4159     12th Ave S Viewpoint      NaN -122.317765  47.577953          34
# 2   4010    14th Ave NW Boat Ramp      NaN -122.373536  47.660775           7
# 3   4010    14th Ave NW Boat Ramp      NaN -122.373536  47.660775           6
# 4   4010    14th Ave NW Boat Ramp      NaN -122.373536  47.660775          36
#
#                  hours              Feature_Desc CHILD_DESC FIELD_TYPE  \
# 0     6 a.m. - 10 p.m.                 Play Area  Play Area        NaN
# 1     6 a.m. - 10 p.m.                      View        NaN        NaN
# 2  4 a.m. - 11:30 p.m.  Boat Launch (Hand Carry)        NaN        NaN
# 3  4 a.m. - 11:30 p.m.   Boat Launch (Motorized)        NaN        NaN
# 4  4 a.m. - 11:30 p.m.                Waterfront        NaN        NaN
#
#    YOUTH_ONLY  LIGHTING                                  Location 1
# 0       False     False    1200 W Howe St\n(-122.372985, 47.636097)
# 1       False     False   2821 12TH Ave S\n(-122.317765, 47.577953)
# 2       False     False  4400 14th Ave NW\n(-122.373536, 47.660775)
# 3       False     False  4400 14th Ave NW\n(-122.373536, 47.660775)
# 4       False     False  4400 14th Ave NW\n(-122.373536, 47.660775)

# %% [markdown]
# #### Step 2 : reformat the column headers in lower case
#
# - the two data sets have some inconsistencies in the header case used on columns so this should be fixed using the str.lower() method.
#
#     - example : df.columns = df.columns.str.lower() function

# %%
df_parks.columns = df_parks.columns.str.lower()
df_facilities.columns = df_facilities.columns.str.lower()

# %%
df_parks.head(5)
# Out:
#    pmaid  locid                     name            address  zip code  \
# 0    281   2545  12th and Howe Play Park     1200 W Howe St     98119
# 1   4159   2387     12th Ave S Viewpoint    2821 12TH Ave S     98144
# 2   4467   2382     12th Ave Square Park       564 12th Ave     98122
# 3   4010   2546    14th Ave NW Boat Ramp   4400 14th Ave NW     98107
# 4    296    296           3001 E Madison  3001 E Madison St     98112
#
#       x coord    y coord                location 1
# 0 -122.372985  47.636097  (47.636097, -122.372985)
# 1 -122.317765  47.577953  (47.577953, -122.317765)
# 2 -122.316455  47.607427  (47.607427, -122.316455)
# 3 -122.373536  47.660775  (47.660775, -122.373536)
# 4 -122.293173  47.625169  (47.625169, -122.293173)

# %%
df_facilities.head(5)
# Out:
#    pmaid                     name alt_name        xpos       ypos  feature_id  \
# 0    281  12th and Howe Play Park      NaN -122.372985  47.636097          22
# 1   4159     12th Ave S Viewpoint      NaN -122.317765  47.577953          34
# 2   4010    14th Ave NW Boat Ramp      NaN -122.373536  47.660775           7
# 3   4010    14th Ave NW Boat Ramp      NaN -122.373536  47.660775           6
# 4   4010    14th Ave NW Boat Ramp      NaN -122.373536  47.660775          36
#
#                  hours              feature_desc child_desc field_type  \
# 0     6 a.m. - 10 p.m.                 Play Area  Play Area        NaN
# 1     6 a.m. - 10 p.m.                      View        NaN        NaN
# 2  4 a.m. - 11:30 p.m.  Boat Launch (Hand Carry)        NaN        NaN
# 3  4 a.m. - 11:30 p.m.   Boat Launch (Motorized)        NaN        NaN
# 4  4 a.m. - 11:30 p.m.                Waterfront        NaN        NaN
#
#    youth_only  lighting                                  location 1
# 0       False     False    1200 W Howe St\n(-122.372985, 47.636097)
# 1       False     False   2821 12TH Ave S\n(-122.317765, 47.577953)
# 2       False     False  4400 14th Ave NW\n(-122.373536, 47.660775)
# 3       False     False  4400 14th Ave NW\n(-122.373536, 47.660775)
# 4       False     False  4400 14th Ave NW\n(-122.373536, 47.660775)

# %% [markdown]
# #### Step 3 : join the data frames together
#
# - use the pandas merge method to combine the two data frames into a new single data frame
# - use the pmaid column as the merge key
#
# https://www.geeksforgeeks.org/merge-two-pandas-dataframes-by-matched-id-number/

# %%
merged_df = pd.merge(df_parks, df_facilities, on="pmaid") 
merged_df
# Out:
#       pmaid  locid                   name_x            address  zip code  \
# 0       281   2545  12th and Howe Play Park     1200 W Howe St     98119
# 1      4159   2387     12th Ave S Viewpoint    2821 12TH Ave S     98144
# 2      4010   2546    14th Ave NW Boat Ramp   4400 14th Ave NW     98107
# 3      4010   2546    14th Ave NW Boat Ramp   4400 14th Ave NW     98107
# 4      4010   2546    14th Ave NW Boat Ramp   4400 14th Ave NW     98107
# ...     ...    ...                      ...                ...       ...
# 1541    200   9909        Woodland Park Zoo      700 N 50th St     98103
# 1542   4563      0         Yesler Playfield     835 Yesler Way     98104
# 1543   4563      0         Yesler Playfield     835 Yesler Way     98104
# 1544    580   1712                York Park  3650 Renton Ave S     98144
# 1545    580   1712                York Park  3650 Renton Ave S     98144
#
#          x coord    y coord              location 1_x  \
# 0    -122.372985  47.636097  (47.636097, -122.372985)
# 1    -122.317765  47.577953  (47.577953, -122.317765)
# 2    -122.373536  47.660775  (47.660775, -122.373536)
# 3    -122.373536  47.660775  (47.660775, -122.373536)
# 4    -122.373536  47.660775  (47.660775, -122.373536)
# ...          ...        ...                       ...
# 1541 -122.350430  47.666183   (47.666183, -122.35043)
# 1542 -122.320083  47.601262  (47.601262, -122.320083)
# 1543 -122.320083  47.601262  (47.601262, -122.320083)
# 1544 -122.295537  47.570461  (47.570461, -122.295537)
# 1545 -122.295537  47.570461  (47.570461, -122.295537)
#
#                        name_y alt_name        xpos       ypos  feature_id  \
# 0     12th and Howe Play Park      NaN -122.372985  47.636097          22
# 1        12th Ave S Viewpoint      NaN -122.317765  47.577953          34
# 2       14th Ave NW Boat Ramp      NaN -122.373536  47.660775           7
# 3       14th Ave NW Boat Ramp      NaN -122.373536  47.660775           6
# 4       14th Ave NW Boat Ramp      NaN -122.373536  47.660775          36
# ...                       ...      ...         ...        ...         ...
# 1541        Woodland Park Zoo      NaN -122.350430  47.666183          17
# 1542         Yesler Playfield      NaN -122.320083  47.601262          41
# 1543         Yesler Playfield      NaN -122.320083  47.601262          45
# 1544                York Park      NaN -122.295537  47.570461          33
# 1545                York Park      NaN -122.295537  47.570461          42
#
#                     hours               feature_desc      child_desc  \
# 0        6 a.m. - 10 p.m.                  Play Area       Play Area
# 1        6 a.m. - 10 p.m.                       View             NaN
# 2     4 a.m. - 11:30 p.m.   Boat Launch (Hand Carry)             NaN
# 3     4 a.m. - 11:30 p.m.    Boat Launch (Motorized)             NaN
# 4     4 a.m. - 11:30 p.m.                 Waterfront             NaN
# ...                   ...                        ...             ...
# 1541  4 a.m. - 11:30 p.m.                     Garden             NaN
# 1542  4 a.m. - 11:30 p.m.  Play Area (ADA Compliant)             NaN
# 1543  4 a.m. - 11:30 p.m.          Baseball/Softball  Baseball Field
# 1544  4 a.m. - 11:30 p.m.                      Paths             NaN
# 1545  4 a.m. - 11:30 p.m.      Paths (ADA Compliant)             NaN
#
#      field_type  youth_only  lighting  \
# 0           NaN       False     False
# 1           NaN       False     False
# 2           NaN       False     False
# 3           NaN       False     False
# 4           NaN       False     False
# ...         ...         ...       ...
# 1541        NaN       False     False
# 1542        NaN       False     False
# 1543        NaN       False     False
# 1544        NaN       False     False
# 1545        NaN       False     False
#
#                                      location 1_y
# 0        1200 W Howe St\n(-122.372985, 47.636097)
# 1       2821 12TH Ave S\n(-122.317765, 47.577953)
# 2      4400 14th Ave NW\n(-122.373536, 47.660775)
# 3      4400 14th Ave NW\n(-122.373536, 47.660775)
# 4      4400 14th Ave NW\n(-122.373536, 47.660775)
# ...                                           ...
# 1541       700 N 50th St\n(-122.35043, 47.666183)
# 1542     835 Yesler Way\n(-122.320083, 47.601262)
# 1543     835 Yesler Way\n(-122.320083, 47.601262)
# 1544  3650 Renton Ave S\n(-122.295537, 47.570461)
# 1545  3650 Renton Ave S\n(-122.295537, 47.570461)
#
# [1546 rows x 20 columns]

# %% [markdown]
# #### step 4: drop unneccesary columns
#
# the columns we want to keep in the resulting data frame are
#
# - zip code
# - x coord
# - y coord
# - locid (location id)
# - name (park name)
# - pmaid (park id)
# - feature_id (facility id)
# - feature_desc (facility description)
#
# drop all remaining columns

# %%
merged_df2 = merged_df[['zip code', 'x coord', 'y coord', 'locid', 'name_x', 'pmaid', 'feature_id', 'feature_desc' ]]
merged_df2.columns
# Out:
# Index(['zip code', 'x coord', 'y coord', 'locid', 'name_x', 'pmaid',
#        'feature_id', 'feature_desc'],
#       dtype='object')

# %% [markdown]
# #### step 5: examine and clean the feature column
#
# - examine the feature_desc column using the pandas function unique()
# - note that this column contains a description of just one facility that a park contains
# - this means each park has multiple rows (one row for each park facility)
# - in some cases you will also see duplicates- this is due to the presence of columns you removed earlier
# - for example, Alki Beach Park (PMAID 445)  has
#     - 2 x boat launches (hand carry)
#     - a fire pit
#     - 2 x paths
#     - picnic sites
#     - 2 x restrooms
#     - a view
#     - a waterfont
# - first, de duplicate the data frame to remove duplicate feature listings
# - remember to reset the index of your data frame after dropping duplicate rows

# %%
# storing unique value in a variable 
merged_df2["feature_desc"].unique()
# Out:
# array(['Play Area', 'View', 'Boat Launch (Hand Carry)',
#        'Boat Launch (Motorized)', 'Waterfront',
#        'Play Area (ADA Compliant)', 'Paths', 'Fire Pit',
#        'Paths (ADA Compliant)', 'Picnic Sites', 'Rental Facility',
#        'Restrooms', 'Restrooms (ADA Compliant)', 'Soccer',
#        'Basketball (Half)', 'Tennis Court (Outdoor)', 'Tennis Lights',
#        'Pesticide Free', 'Baseball/Softball', 'Community Center',
#        'Green Space', 'Woods', 'Adult Fitness Equipment',
#        'Basketball (Full)', 'Skatepark', 'Wading Pool or Water Feature',
#        'Pool (Indoor)', 'Tennis Backboard (Outdoor)', 'Historic Landmark',
#        'P-Patch Community Garden', 'Weddings and Ceremonies', 'Fishing',
#        'T-Ball', 'Dog Off Leash Area', 'Community Building', 'Garden',
#        'Environmental Learning Center', 'Hiking Trails', 'Creek',
#        'Picnic Sites (ADA Compliant)', 'Football', 'Skate Dot',
#        'U-8 Soccer', 'Track', 'Decorative Fountain', 'Golf',
#        'Guarded Beach', 'Skatespot', 'Rugby', 'Bike Trail', 'Cricket',
#        'Lawn Bowling', 'Bike Polo', 'Model Boat Pond', 'Boat Moorage',
#        'Horseshoe Pits', 'Pool (Outdoor)', 'Zipline', 'Pickleball Court',
#        'Disc Golf', 'Tidelands', 'Marination Ma Kai', 'Scuba Diving',
#        'NO Beach Access', 'Flag Football', 'Lacrosse', 'Ultimate',
#        'BMX Dirt Jumps'], dtype=object)

# %%
df3 = merged_df2.drop_duplicates(subset=['name_x','feature_desc'])

# %%
df3[df3['pmaid']==445]
# Out:
#     zip code     x coord    y coord  locid           name_x  pmaid  \
# 12     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 14     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 15     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 16     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 17     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 18     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 19     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 20     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 21     98116 -122.402173  47.582912   1888  Alki Beach Park    445
# 22     98116 -122.402173  47.582912   1888  Alki Beach Park    445
#
#     feature_id               feature_desc
# 12           7   Boat Launch (Hand Carry)
# 14          14                   Fire Pit
# 15          33                      Paths
# 16          42      Paths (ADA Compliant)
# 17          21               Picnic Sites
# 18          26            Rental Facility
# 19          27                  Restrooms
# 20          40  Restrooms (ADA Compliant)
# 21          34                       View
# 22          36                 Waterfront

# %%
df3.reset_index(drop=True)
# Out:
#       zip code     x coord    y coord  locid                   name_x  pmaid  \
# 0        98119 -122.372985  47.636097   2545  12th and Howe Play Park    281
# 1        98144 -122.317765  47.577953   2387     12th Ave S Viewpoint   4159
# 2        98107 -122.373536  47.660775   2546    14th Ave NW Boat Ramp   4010
# 3        98107 -122.373536  47.660775   2546    14th Ave NW Boat Ramp   4010
# 4        98107 -122.373536  47.660775   2546    14th Ave NW Boat Ramp   4010
# ...        ...         ...        ...    ...                      ...    ...
# 1301     98103 -122.350430  47.666183   9909        Woodland Park Zoo    200
# 1302     98104 -122.320083  47.601262      0         Yesler Playfield   4563
# 1303     98104 -122.320083  47.601262      0         Yesler Playfield   4563
# 1304     98144 -122.295537  47.570461   1712                York Park    580
# 1305     98144 -122.295537  47.570461   1712                York Park    580
#
#       feature_id               feature_desc
# 0             22                  Play Area
# 1             34                       View
# 2              7   Boat Launch (Hand Carry)
# 3              6    Boat Launch (Motorized)
# 4             36                 Waterfront
# ...          ...                        ...
# 1301          17                     Garden
# 1302          41  Play Area (ADA Compliant)
# 1303          45          Baseball/Softball
# 1304          33                      Paths
# 1305          42      Paths (ADA Compliant)
#
# [1306 rows x 8 columns]

# %% [markdown]
# #### step 6 : turn the feature column into multiple boolean facility 1/0 columns
#
# - we want a list of parks alongside columns for all the possible features, showing which feature each park contains
# - there are 68 feature described in total, and you will see that some features are very similar (eg basketball(full)/ basketball(half)) so OPTIONALLY you can pause here to reduce those features using text analysis methods you learnt in topic 8.
# - use the pandas pivot_table method to pivot the feature desciption column into multiple columns which will change the shape of the data from long to wide
#
#     - example:  pd.pivot_table(df, index=[park], columns=[feature],aggfunc="count")
#
# - replace the NaN entries in the resulting df with 0 with the pandas fillna() method

# %%
df3['feature_desc'].unique()
# Out:
# array(['Play Area', 'View', 'Boat Launch (Hand Carry)',
#        'Boat Launch (Motorized)', 'Waterfront',
#        'Play Area (ADA Compliant)', 'Paths', 'Fire Pit',
#        'Paths (ADA Compliant)', 'Picnic Sites', 'Rental Facility',
#        'Restrooms', 'Restrooms (ADA Compliant)', 'Soccer',
#        'Basketball (Half)', 'Tennis Court (Outdoor)', 'Tennis Lights',
#        'Pesticide Free', 'Baseball/Softball', 'Community Center',
#        'Green Space', 'Woods', 'Adult Fitness Equipment',
#        'Basketball (Full)', 'Skatepark', 'Wading Pool or Water Feature',
#        'Pool (Indoor)', 'Tennis Backboard (Outdoor)', 'Historic Landmark',
#        'P-Patch Community Garden', 'Weddings and Ceremonies', 'Fishing',
#        'T-Ball', 'Dog Off Leash Area', 'Community Building', 'Garden',
#        'Environmental Learning Center', 'Hiking Trails', 'Creek',
#        'Picnic Sites (ADA Compliant)', 'Football', 'Skate Dot',
#        'U-8 Soccer', 'Track', 'Decorative Fountain', 'Golf',
#        'Guarded Beach', 'Skatespot', 'Rugby', 'Bike Trail', 'Cricket',
#        'Lawn Bowling', 'Bike Polo', 'Model Boat Pond', 'Boat Moorage',
#        'Horseshoe Pits', 'Pool (Outdoor)', 'Zipline', 'Pickleball Court',
#        'Disc Golf', 'Tidelands', 'Marination Ma Kai', 'Scuba Diving',
#        'NO Beach Access', 'Flag Football', 'Lacrosse', 'Ultimate',
#        'BMX Dirt Jumps'], dtype=object)

# %%
# Assuming your initial DataFrame is named df3
# Drop unnecessary columns except 'name_x' and 'feature_desc'
df3 = df3[['name_x', 'feature_desc']]

# Define the feature mapping dictionary
feature_mapping = {
    'Play Area (ADA Compliant)': 'Play Area',
    'Restrooms (ADA Compliant)': 'Restrooms',
    'Paths (ADA Compliant)': 'Paths',
    'Wading Pool or Water Feature': 'Pool',
    'Pool (Outdoor)': 'Pool',
    'Soccer': 'Football',
    'U-8 Soccer': 'Football',
    'Flag Football': 'Football',
    'Skate Dot': 'Skate Park',
    'Skatespot': 'Skate Park',
    'Tennis Court (Outdoor)': 'Tennis',
    'Tennis Lights': 'Tennis',
    'Tennis Backboard (Outdoor)': 'Tennis',
    'Community Building': 'Community Center',
    'P-Patch Community Garden': 'Garden',
    'Green Space': 'Garden',
    'Basketball (Full)': 'Basketball',
    'Basketball (Half)': 'Basketball',
    'Boat Launch (Hand Carry)': 'Boat Launch',
    'Boat Launch (Motorized)': 'Boat Launch',
    'Boat Moorage': 'Boat Launch',
    'Model Boat Pond': 'Boat Launch'
    # Add more mappings as needed
}

# Replace values in 'feature_desc' based on the mapping
df3['feature_desc'] = df3['feature_desc'].replace(feature_mapping)

# Group by 'name_x' and aggregate 'feature_desc' values
df3_grouped = df3.groupby('name_x')['feature_desc'].agg(', '.join).reset_index()

# Display the updated and grouped DataFrame
df3_grouped['feature_desc']
# Out:
# array(['View', 'Play Area', 'Boat Launch, Boat Launch, Waterfront',
#        'Boat Launch', 'Paths, View', 'Boat Launch, Waterfront',
#        'Boat Launch, Fire Pit, Paths, Paths, Picnic Sites, Rental Facility, Restrooms, Restrooms, View, Waterfront',
#        'Football, Basketball, Tennis, Tennis, Pesticide Free, Baseball/Softball, Community Center, Play Area, Restrooms',
#        'Paths', 'Tennis', 'View, Waterfront', 'Garden, Woods',
#        'Adult Fitness Equipment, Paths, Paths, Play Area',
#        'Play Area, Baseball/Softball, Football, Basketball, Basketball',
#        'Paths, Pesticide Free, Play Area', 'Skatepark, Pool',
#        'Play Area, Baseball/Softball, Football, Pool (Indoor), Community Center',
#        'Baseball/Softball',
#        'Basketball, Football, View, Restrooms, Play Area, Baseball/Softball',
#        'Tennis, Restrooms, Baseball/Softball, Restrooms, Basketball, Football, Play Area, Pool, Tennis',
#        'Boat Launch, Pesticide Free, Picnic Sites, Play Area, Restrooms, View, Waterfront',
#        'Paths, Paths', 'Historic Landmark, Garden',
#        'View, Weddings and Ceremonies',
#        'Fishing, Boat Launch, Pesticide Free, View, Waterfront',
#        'Skatepark, Basketball, Pesticide Free, Basketball, Picnic Sites, Play Area, Paths, View',
#        'Play Area, View, Weddings and Ceremonies',
#        'Tennis, Tennis, Community Center, Play Area, Pool, T-Ball, Restrooms, Waterfront, Football, Baseball/Softball',
#        'Adult Fitness Equipment, Paths, Play Area, Garden',
#        'Dog Off Leash Area',
#        'Community Center, Garden, Pesticide Free, Play Area, Garden, Restrooms, Restrooms, View',
#        'Restrooms, Basketball, Football, Baseball/Softball, Basketball, Tennis, Play Area',
#        'Play Area, Basketball, Tennis',
#        'Basketball, Restrooms, Paths, Play Area, Restrooms',
#        'Baseball/Softball, Historic Landmark, Paths, Paths, Play Area, Rental Facility, Restrooms, Football, Tennis, Tennis, Pool',
#        'Environmental Learning Center, Hiking Trails, Paths, Paths, Rental Facility, Restrooms, Restrooms, Weddings and Ceremonies, Woods',
#        'Boat Launch, Creek, Environmental Learning Center, Hiking Trails, Paths, Picnic Sites, Picnic Sites (ADA Compliant), Play Area, Rental Facility, Restrooms, Restrooms, View, Waterfront, Weddings and Ceremonies, Woods',
#        'Garden, Restrooms, Basketball, Restrooms, Play Area',
#        'Paths, Paths, Play Area', 'Boat Launch, View, Waterfront',
#        'Basketball', 'Football, Football, Tennis', 'Garden',
#        'Waterfront, Baseball/Softball, Paths, Garden, Football, Weddings and Ceremonies, Woods',
#        'Basketball, Play Area, Restrooms',
#        'Paths, Paths, Restrooms, Restrooms, View', 'Paths, Play Area',
#        'Baseball/Softball, Basketball, Creek, Hiking Trails, Historic Landmark, Paths, Play Area, Rental Facility, Restrooms, Tennis, Woods',
#        'Paths, Woods',
#        'Paths, Play Area, Skate Park, Skatepark, T-Ball, Football',
#        'Baseball/Softball, Basketball, Play Area, Restrooms, Skatepark, Football, Pool',
#        'Paths, Play Area, Restrooms, Tennis, Tennis, Track, Woods',
#        'Boat Launch, Pesticide Free, View, Waterfront',
#        'Hiking Trails, Paths, Paths, Play Area, Tennis, Woods',
#        'Pool, Restrooms, Baseball/Softball, Community Center, Play Area, Football, Basketball, Tennis, Restrooms, Skatepark',
#        'Pesticide Free', 'View, Waterfront, Weddings and Ceremonies',
#        'Dog Off Leash Area, Paths, Paths, Play Area',
#        'Basketball, Environmental Learning Center, Hiking Trails, Historic Landmark, Paths, Paths, Play Area, Rental Facility, Restrooms, Restrooms, Tennis, View, Waterfront, Weddings and Ceremonies, Woods',
#        'Boat Launch, Boat Launch, Paths, Picnic Sites, Restrooms, View, Waterfront, Weddings and Ceremonies',
#        'Community Center, Paths, Paths, Play Area, Restrooms',
#        'Dog Off Leash Area, Hiking Trails, Paths, Picnic Sites, Play Area, Restrooms, View, Woods',
#        'Baseball/Softball, Basketball, Pool, Football, Play Area, Restrooms',
#        'Waterfront',
#        'Basketball, Baseball/Softball, Pool, Restrooms, Football, Restrooms, Play Area',
#        'Boat Launch, Boat Launch, Fishing, Waterfront', 'View, Play Area',
#        'Waterfront, Weddings and Ceremonies, Paths, View',
#        'Play Area, Football, Baseball/Softball, Restrooms, Pesticide Free',
#        'View, Boat Launch, Fishing, Garden, Waterfront',
#        'Creek, Garden, Hiking Trails, Paths, Woods',
#        'Boat Launch, Picnic Sites', 'Basketball, Play Area',
#        'Decorative Fountain, Paths, Paths', 'View, Paths, Waterfront',
#        'Creek, Hiking Trails, Paths, Woods', 'Tennis, Play Area',
#        'Community Center, Restrooms, Tennis, Baseball/Softball, Play Area, Restrooms, Football, Tennis, Football, Pool (Indoor)',
#        'Historic Landmark, Paths, Paths, Picnic Sites, Play Area, Restrooms, Restrooms, View, Waterfront, Weddings and Ceremonies',
#        'Dog Off Leash Area, Hiking Trails, Paths, Paths, Picnic Sites, Play Area, Restrooms, Restrooms, Football',
#        'Restrooms, Basketball, Restrooms, Pool, Play Area, Tennis, Football',
#        'Tennis, Baseball/Softball, Basketball, Restrooms, Play Area, Pool, Football',
#        'Basketball, Boat Launch, Creek, Dog Off Leash Area, Fire Pit, Hiking Trails, Paths, Paths, Picnic Sites, Play Area, Rental Facility, Restrooms, Restrooms, View, Waterfront, Weddings and Ceremonies',
#        'Baseball/Softball, Basketball, Boat Launch, Community Center, Fishing, Golf, Guarded Beach, Paths, Paths, Play Area, Pool (Indoor), Rental Facility, Restrooms, Restrooms, Football, Tennis, Pool, Waterfront, Woods',
#        'View, Weddings and Ceremonies, Woods',
#        'Restrooms, Tennis, Play Area, Tennis, Restrooms, Track, Baseball/Softball, Paths, Paths, Historic Landmark, Football, Tennis, Basketball, Community Center, Pool',
#        'Play Area, Baseball/Softball, T-Ball, Restrooms, Football, Tennis, Pool',
#        'Restrooms, Restrooms', 'Hiking Trails, Paths',
#        'Paths, Play Area, View', 'Adult Fitness Equipment, Skate Park',
#        'Restrooms, Football, Baseball/Softball, Restrooms, Tennis, Rugby, Basketball, Play Area',
#        'Bike Trail, Dog Off Leash Area, Paths, View',
#        'Football, Baseball/Softball, Restrooms, Restrooms, T-Ball',
#        'Golf', 'Bike Trail, Hiking Trails, Paths, Woods', 'Golf, Garden',
#        'View, Baseball/Softball, Basketball, Community Center, Cricket, Lawn Bowling, Paths, Picnic Sites, Play Area, Rental Facility, Skatepark, Football, Tennis, Tennis, Pool, Weddings and Ceremonies',
#        'Adult Fitness Equipment, Basketball, Basketball, Paths, Picnic Sites, Play Area, Restrooms, Pool',
#        'Baseball/Softball, Basketball, Bike Polo, Decorative Fountain, Football, Paths, Paths, Picnic Sites, Play Area, Restrooms, Skate Park, Football, Pool',
#        'Garden, Paths',
#        'Basketball, Play Area, View, Weddings and Ceremonies',
#        'Dog Off Leash Area, Hiking Trails, Historic Landmark, Paths, Play Area, Restrooms, Tennis, View, Weddings and Ceremonies, Woods',
#        'Play Area, Garden', 'Garden, Woods, View',
#        'Garden, Historic Landmark, Paths, Weddings and Ceremonies',
#        'Hiking Trails, Paths, View',
#        'Boat Launch, Boat Launch, Paths, Pesticide Free, Rental Facility, View, Pool, Waterfront',
#        'Creek, Garden, Hiking Trails, Play Area, Woods',
#        'Baseball/Softball, Basketball, Restrooms, Restrooms',
#        'Pesticide Free, Football, Play Area, Restrooms, Baseball/Softball',
#        'Baseball/Softball, Tennis, Play Area, Tennis, Football, Community Center, Tennis',
#        'Baseball/Softball, Hiking Trails, Play Area, Football, Woods',
#        'Boat Launch, Boat Launch, Paths, Play Area, Restrooms, Tennis, View, Woods',
#        'Garden, Hiking Trails',
#        'Hiking Trails, Paths, Play Area, Restrooms, Weddings and Ceremonies, Woods',
#        'Baseball/Softball, Boat Launch, Hiking Trails, Horseshoe Pits, Paths, Picnic Sites, Play Area, Pool, Garden, Restrooms, Restrooms, Football, View, Pool, Woods',
#        'Creek, Play Area, Restrooms',
#        'Paths, Weddings and Ceremonies, Woods',
#        'Boat Launch, Play Area, Tennis, View, Waterfront',
#        'Play Area, Baseball/Softball, Community Center, Football, Basketball, Restrooms',
#        'Guarded Beach, Play Area, Rental Facility, Tennis, Tennis, View, Waterfront, Weddings and Ceremonies',
#        'Play Area, View, Waterfront',
#        'Creek, Guarded Beach, Hiking Trails, Paths, Picnic Sites, Play Area, Restrooms, View, Waterfront, Weddings and Ceremonies, Woods',
#        'Play Area, Tennis, Basketball, Basketball, Rental Facility, Tennis, Restrooms, Football, Baseball/Softball',
#        'Community Center, Paths, Picnic Sites, Play Area, Restrooms, Tennis, View, Waterfront, Weddings and Ceremonies, Woods',
#        'Baseball/Softball, Tennis, Football, Restrooms, T-Ball, Restrooms, Pool, Play Area',
#        'Restrooms, Paths, Football, Zipline, Restrooms, Basketball, Play Area, Baseball/Softball, Pickleball Court',
#        'Baseball/Softball, Paths, Restrooms, Play Area, Restrooms, Basketball, Football, Paths',
#        'Boat Launch, Hiking Trails, Paths, View, Waterfront',
#        'Boat Launch, Creek, Guarded Beach, Hiking Trails, Paths, Picnic Sites, Play Area, Restrooms, Restrooms, View, Waterfront',
#        'Pesticide Free, Play Area', 'Paths, Picnic Sites, Woods',
#        'Baseball/Softball, Tennis, Restrooms, Tennis, Pool (Indoor), Play Area, Creek, Paths, Restrooms, Community Center',
#        'Picnic Sites, Basketball, Play Area, Pesticide Free, Weddings and Ceremonies, Restrooms',
#        'Decorative Fountain, Tennis, Pool, Football, Play Area, Baseball/Softball, Community Center, Tennis, Restrooms, Basketball',
#        'Disc Golf, Paths',
#        'Football, Play Area, Paths, Paths, Baseball/Softball, Restrooms, Restrooms, Community Center, Waterfront, Tennis, Track, View, Football',
#        'Creek, Fishing, Guarded Beach, Hiking Trails, Paths, Play Area, Restrooms, Restrooms, Tennis, Tennis, View, Waterfront, Weddings and Ceremonies, Woods',
#        'Bike Trail, Paths, Paths, View, Waterfront',
#        'Creek, Garden, Woods',
#        'Baseball/Softball, Dog Off Leash Area, Hiking Trails, Paths, Picnic Sites, Play Area, Restrooms, Restrooms, Football, Pool, Woods',
#        'Garden, Hiking Trails, Woods',
#        'Decorative Fountain, Paths, Restrooms', 'Tidelands, Waterfront',
#        'Restrooms, Basketball, Restrooms, Paths, Basketball, Play Area, Picnic Sites',
#        'Garden, Historic Landmark, Weddings and Ceremonies',
#        'Play Area, Restrooms, Pool, Restrooms',
#        'Basketball, Play Area, Restrooms, Football, Baseball/Softball',
#        'Decorative Fountain, Historic Landmark',
#        'Dog Off Leash Area, View',
#        'Basketball, Play Area, Restrooms, Restrooms, Pool',
#        'Basketball, Basketball, Decorative Fountain, Paths, Paths, Picnic Sites, Play Area, Restrooms, Restrooms, Pool',
#        'Decorative Fountain',
#        'Guarded Beach, Paths, Rental Facility, Restrooms, Restrooms, View, Waterfront, Weddings and Ceremonies',
#        'Lawn Bowling, Garden, Woods', 'Creek, Hiking Trails, Woods',
#        'Track, Restrooms, Football',
#        'Restrooms, Tennis, Football, Baseball/Softball, Play Area, Tennis, Pool (Indoor), Restrooms, Community Center',
#        'Basketball, Community Center, Play Area, Tennis, Tennis, Baseball/Softball, Football',
#        'Baseball/Softball, Creek, Hiking Trails, Paths, Picnic Sites, Play Area, Restrooms, Restrooms, Football, Tennis, Tennis, Pool, Woods',
#        'Basketball, Community Center, Play Area, Tennis',
#        'Dog Off Leash Area, Pesticide Free',
#        'Baseball/Softball, Basketball, Play Area, Restrooms, Football, Tennis, Woods',
#        'Restrooms, Football, Play Area, Baseball/Softball, Restrooms',
#        'Basketball, Baseball/Softball, Play Area, Restrooms, Rental Facility, T-Ball',
#        'Baseball/Softball, Picnic Sites, Play Area, Restrooms, Skatepark, Football',
#        'Play Area, Restrooms',
#        'Play Area, Restrooms, Restrooms, Football, Tennis, View',
#        'Play Area, Restrooms, Pool, Basketball, Restrooms',
#        'Boat Launch, Fishing, Marination Ma Kai, Scuba Diving, View, Waterfront',
#        'Garden, NO Beach Access, View, Woods',
#        'Boat Launch, Environmental Learning Center, Guarded Beach, Hiking Trails, Paths, Paths, Picnic Sites, Play Area, Restrooms, Restrooms, Tennis, View, Waterfront, Weddings and Ceremonies, Woods',
#        'Paths, Garden, Tennis, Tennis, Tennis',
#        'Restrooms, Football, Rugby, Play Area, Tennis, Baseball/Softball, Football, View, Pool',
#        'Community Center, Pool, Play Area, Baseball/Softball, Football, Tennis',
#        'Boat Launch, Boat Launch, Fishing, Paths, Paths, Waterfront',
#        'Paths, Paths, View', 'Boat Launch, Boat Launch, View',
#        'Pesticide Free, Paths, Play Area',
#        'Boat Launch, Fishing, View, Waterfront', 'Paths, Garden',
#        'Play Area, Garden, View',
#        'Restrooms, Tennis, Play Area, Pesticide Free, Tennis, Adult Fitness Equipment, Football, Baseball/Softball',
#        'Restrooms, Pool, Community Center, Baseball/Softball, Play Area, Football, Basketball',
#        'Restrooms, View', 'Creek, Play Area, Woods',
#        'Basketball, Tennis, Play Area',
#        'Baseball/Softball, Basketball, Paths, Paths, Play Area, Restrooms, Football, Pool',
#        'Woods',
#        'Restrooms, Historic Landmark, Paths, Play Area, Restrooms, Tennis, Tennis, Tennis, Pool',
#        'Garden, Weddings and Ceremonies',
#        'Paths, Play Area, T-Ball, Tennis, Restrooms, Restrooms, Pool, Football',
#        'Football, Play Area, Restrooms, Football, Restrooms, Baseball/Softball, Tennis, Community Center',
#        'Paths, Play Area, Rental Facility, View',
#        'Baseball/Softball, Bike Trail, Boat Launch, Boat Launch, Community Center, Cricket, Dog Off Leash Area, Guarded Beach, Hiking Trails, Lacrosse, Paths, Paths, Picnic Sites, Play Area, Garden, Rental Facility, Restrooms, Restrooms, Rugby, Football, Tennis, Ultimate, View, Pool, Waterfront',
#        'Boat Launch, Creek, Fishing, Garden, Hiking Trails, Paths, Play Area, Restrooms, View, Waterfront, Weddings and Ceremonies, Woods',
#        'Baseball/Softball, Football',
#        'Historic Landmark, View, Waterfront', 'Fishing, View, Waterfront',
#        'Paths, View, Waterfront', 'Pesticide Free, View, Waterfront',
#        'Baseball/Softball, Community Center, Pool (Indoor), Football, Play Area',
#        'Golf, Restrooms, Weddings and Ceremonies',
#        'Football, Restrooms, Restrooms',
#        'Dog Off Leash Area, Hiking Trails, Paths, Picnic Sites, Play Area, Restrooms, Woods',
#        'Decorative Fountain, Play Area',
#        'Baseball/Softball, BMX Dirt Jumps, Decorative Fountain, Dog Off Leash Area, Horseshoe Pits, Lawn Bowling, Paths, Picnic Sites, Play Area, Rental Facility, Restrooms, Restrooms, Skatepark, Football, Tennis, Tennis, Track, Woods',
#        'Play Area, Baseball/Softball'], dtype=object)

# %%
# df4[df4['feature_']]

# %%
# df4 = pd.pivot_table(df3, values=['feature_id'], index=['name_x'], columns=['feature_desc'], aggfunc="count")

# %%
df5 = df4.fillna(0)
df5

# %%
len(df5.columns)

# %%
df5.columns

# %% [markdown]
# #### Step 7: validate the data
# - use EDA techniques including visualisation to validate the reshaping process

# %%
# df3[['feature_desc', 'name_x']].groupby('feature_desc').count()
