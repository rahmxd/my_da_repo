# %%
import pandas as pd

# %%
# Question 1
titanic = pd.read_csv('titanic.csv')
titanic.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
# Question 2
condition = titanic['fare'] < 100
# or titanic.fare < 100

result = titanic[condition]
result.head()
# Out:
#    pclass  survived                                           name     sex  \
# 5       1         1                            Anderson, Mr. Harry    male
# 6       1         1              Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                         Andrews, Mr. Thomas Jr    male
# 8       1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                        Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch     fare
# 5  48.0      0      0  26.5500
# 6  63.0      1      0  77.9583
# 7  39.0      0      0   0.0000
# 8  53.0      2      0  51.4792
# 9  71.0      0      0  49.5042

# %%
# Question 3
titanic['age']
#or titanic.age
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
# Question 4
selection1 = titanic[['pclass', 'sex', 'age']]
selection1
# Out:
#       pclass     sex      age
# 0          1  female  29.0000
# 1          1    male   0.9167
# 2          1  female   2.0000
# 3          1    male  30.0000
# 4          1  female  25.0000
# ...      ...     ...      ...
# 1304       3  female  14.5000
# 1305       3  female      NaN
# 1306       3    male  26.5000
# 1307       3    male  27.0000
# 1308       3    male  29.0000
#
# [1309 rows x 3 columns]

# %%
# Question 5
titanic['age'].count()
# Out:
# 1046

# %%
# Question 6
titanic.dtypes
#or titanic.info()
# Out:
# pclass        int64
# survived      int64
# name         object
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# dtype: object

# %%
# Question 7
# Note that these solutions change the parch column to float rather than int as it's already int.
# This is so you can see that the method has worked when you check the data types.
titanic['parch'] = titanic['parch'].astype(float)
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch      fare
# 0     female  29.0000      0    0.0  211.3375
# ...

# %%
titanic.dtypes
# Out:
# pclass        int64
# survived      int64
# name         object
# sex          object
# age         float64
# sibsp         int64
# parch       float64
# fare        float64
# dtype: object

# %%
# Question 8
titanic.groupby('sex').count()
# Out:
#         pclass  survived  name  age  sibsp  parch  fare
# sex
# female     466       466   466  388    466    466   466
# male       843       843   843  658    843    843   842
